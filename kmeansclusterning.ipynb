# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib as plt

# %%
df = sns.load_dataset('titanic')
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 0      man        True  NaN  Southampton    no  False
# 1    woman       False    C    Cherbourg   yes  False
# 2    woman       False  NaN  Southampton   yes   True
# 3    woman       False    C  Southampton   yes  False
# 4      man        True  NaN  Southampton    no   True
# ..     ...         ...  ...          ...   ...    ...
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True
#
# [891 rows x 15 columns]

# %%
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
x=df[['age', 'fare']]
x.age.fillna(value=x['age'].mean(),inplace=True)
#Scaller
scaler= StandardScaler()
X_scaled = scaler.fit_transform(x)
# Out:
# C:\Users\M.Sikandar\AppData\Local\Temp\ipykernel_16256\894089687.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x.age.fillna(value=x['age'].mean(),inplace=True)

# %%
X_scaled
# Out:
# array([[-0.53037664, -0.50244517],
#        [ 0.57183099,  0.78684529],
#        [-0.25482473, -0.48885426],
#        ...,
#        [        nan, -0.17626324],
#        [-0.25482473, -0.04438104],
#        [ 0.15850313, -0.49237783]])

# %%
x.head()
# Out:
#     age     fare
# 0  22.0   7.2500
# 1  38.0  71.2833
# 2  26.0   7.9250
# 3  35.0  53.1000
# 4  35.0   8.0500

# %%
model= KMeans(n_clustrs=3)
model.fit(X_scaled)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 model= KMeans(n_clustrs=3)
#       2 model.fit(X_scaled)
#
# TypeError: KMeans.__init__() got an unexpected keyword argument 'n_clustrs'
